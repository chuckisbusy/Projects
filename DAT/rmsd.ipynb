# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
# %matplotlib inline

# %%
rcParams['figure.figsize'] = 10,10
rcParams['axes.linewidth'] = 4.0
rcParams['savefig.dpi'] = 500
rcParams['pdf.fonttype'] = 42
rcParams['ps.fonttype'] = 42

# %% [markdown]
# # DAT

# %%
datafile1="/home/cad234/projects/SRI/42619/MD/rest-5ns-wat/ptraj/equil.rms-bb.rmsfit"
datafile2="/home/cad234/projects/SRI/42619/MD/rest-5ns-wat/ptraj/equil.lig-nofit.rmsfit"
datafile3="/home/cad234/projects/SRI/42619/MD/rest-5ns-wat/ptraj/equil.lig.rmsfit"
data1=np.loadtxt(datafile1,comments='#',usecols=1)
data2=np.loadtxt(datafile2,comments='#',usecols=1)
data3=np.loadtxt(datafile3,comments='#',usecols=1)

# %%
x = np.arange(len(data))/1000
plt.plot(x,data1,label='Backbone',color='C0')
plt.plot(x,data2,label='Ligand nofit',color='red')
#plt.plot(x,data3)
leg = plt.legend(fontsize=18,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)

plt.ylabel("RMSD ($\AA$)", fontsize=30)
plt.yticks(fontsize=28)
plt.xlabel("Time (ns)", fontsize=30)
plt.xticks(fontsize=28)
plt.tick_params(axis='both',labelsize='25', length=7, width=5)
plt.tight_layout()
plt.savefig("../figs/dat-rmsd.pdf", transparent=True)

# %% [markdown]
# # NET

# %%
datafile4="/home/cad234/projects/NET/rest-5ns-wat/ptraj/equil.rms-bb.rmsfit"
datafile5="/home/cad234/projects/NET/rest-5ns-wat/ptraj/equil.lig-nofit.rmsfit"
datafile6="/home/cad234/projects/NET/rest-5ns-wat/ptraj/equil.lig.rmsfit"
data4=np.loadtxt(datafile4,comments='#',usecols=1)
data5=np.loadtxt(datafile5,comments='#',usecols=1)
data6=np.loadtxt(datafile6,comments='#',usecols=1)

# %%
x = np.arange(len(data))/1000
plt.plot(x,data4,label='Backbone',color='C0')
plt.plot(x,data5,label='Ligand nofit',color='red')
#plt.plot(x,data6)
leg = plt.legend(fontsize=18,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)

plt.ylabel("RMSD ($\AA$)", fontsize=30)
plt.yticks(fontsize=28)
plt.xlabel("Time (ns)", fontsize=30)
plt.xticks(fontsize=28)
plt.tick_params(axis='both',labelsize='25', length=7, width=5)
plt.tight_layout()
plt.savefig("../figs/net-rmsd.pdf", transparent=True)
