# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pylab as plt
import re
import os
import glob
from matplotlib import rcParams
from sklearn import linear_model
from sklearn import metrics
# %matplotlib inline

# %%
rcParams['figure.figsize'] = 10,10
rcParams['axes.linewidth'] = 4.0
rcParams['savefig.dpi'] = 500
rcParams['pdf.fonttype'] = 42
rcParams['ps.fonttype'] = 42

# %% [markdown]
# # Glide Docking Score

# %%
#Conf 1
tmp=[]
df=[]
os.chdir("/home/cad234/projects/pde2/glide-pde-conf1/vsw_test")
all_filenames=[i for i in glob.glob('vsw_test-DOCK_XP_1-*.{}'.format("csv"))]
for f in all_filenames:
    tmp=pd.read_csv(f, header=0, sep=',', engine='python')
    tmp.sort_values(by=['r_i_docking_score'], inplace=True)
    tmp.drop_duplicates(['title'], inplace=True)
    df.append(tmp)
dF1=pd.concat(df, axis=0, ignore_index=True)
dF1.drop(dF1.columns.difference(['title','r_i_docking_score']), 1, inplace=True)
dF1.rename(columns={'r_i_docking_score': 'Conf 1'}, inplace=True)

# %%
#Conf 2
tmp=[]
df=[]
os.chdir("/home/cad234/projects/pde2/glide-pde-conf2/vsw_test-DOCK_XP_1-001.csv")
all_filenames=[i for i in glob.glob('vsw_4_htvs_sp-DOCK_SP_1-*.{}'.format("csv"))]
for f in all_filenames:
    tmp=pd.read_csv(f, header=0, sep=',', engine='python')
    tmp.sort_values(by=['r_i_docking_score'], inplace=True)
    tmp.drop_duplicates(['title'], inplace=True)
    df.append(tmp)
dF2=pd.concat(df, axis=0, ignore_index=True)
dF2.drop(dF2.columns.difference(['title','r_i_docking_score']), 1, inplace=True)
dF2.rename(columns={'r_i_docking_score': 'Conf 2'}, inplace=True)

# %%
combined=pd.merge(dF1, dF2, how='outer', on='title')
combined['Lowest'] = combined[['Conf 1','Conf 2']].min(axis=1)
combined.sort_values(by=['Lowest'], inplace=True)
combined["Rank"] = combined['Lowest'].rank(method='first')
combined.sort_values(['title'], inplace=True)

# %%
allIC50=pd.read_excel("/home/cad234/ipn/PDE2/all.xls", header=0)
#fin1=pd.merge(combined, allIC50, how='outer', on='title')
fin1=pd.merge(dF1, allIC50, how='outer', on='title')
fin1.to_csv( "/home/cad234/ipn/PDE2/DOCK_XP.csv", index=False)

# %% [markdown]
# # MMGBSA Binding free energy

# %% [markdown]
# ## Conf 1

# %%
dG1_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/lists/list1.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG1_total = line.split()
                dG1_list.append(dG1_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG1_list.append(non)
list1c1 = pd.DataFrame({'title': title,'dG conf1': dG1_list})

# %%
dG2_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/lists/list2.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG2_total = line.split()
                dG2_list.append(dG2_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG2_list.append(non)
list2c1 = pd.DataFrame({'title': title,'dG conf1': dG2_list})

# %%
dG3_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/lists/list3.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG3_total = line.split()
                dG3_list.append(dG3_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG3_list.append(non)
list3c1 = pd.DataFrame({'title': title,'dG conf1': dG3_list})

# %%
dG4_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/lists/list4.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG4_total = line.split()
                dG4_list.append(dG4_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG4_list.append(non)
list4c1 = pd.DataFrame({'title': title,'dG conf1': dG4_list})

# %%
dG5_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/lists/list5.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf1/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG5_total = line.split()
                dG5_list.append(dG5_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG5_list.append(non)
list5c1 = pd.DataFrame({'title': title,'dG conf1': dG5_list})

# %% [markdown]
# ## Conf 2

# %%
dG1_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/lists/list1.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG1_total = line.split()
                dG1_list.append(dG1_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG1_list.append(non)
list1c2 = pd.DataFrame({'title': title,'dG conf2': dG1_list})

# %%
dG2_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/lists/list2.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG2_total = line.split()
                dG2_list.append(dG2_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG2_list.append(non)
list2c2 = pd.DataFrame({'title': title,'dG conf2': dG2_list})

# %%
dG3_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/lists/list3.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG3_total = line.split()
                dG3_list.append(dG3_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG3_list.append(non)
list3c2 = pd.DataFrame({'title': title,'dG conf2': dG3_list})

# %%
dG4_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/lists/list4.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG4_total = line.split()
                dG4_list.append(dG4_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG4_list.append(non)
list4c2 = pd.DataFrame({'title': title,'dG conf2': dG4_list})

# %%
dG5_list=[]
title=[]

file="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/lists/list5.txt"
readFile = open(file, "r")
for cmpd in readFile:
    cmpd = cmpd.strip()
    #print (line)
    title.append(cmpd)
    gbsa="/home/chuck/u1/pde2/glide-pde-conf2/vsw_xp_1/5000/amber/"+cmpd+"/pbsa/Results.dat"
    try:
        readGbsa = open(gbsa, "r")
        for line in readGbsa:
            line = line.strip() # strip end-on-line
            if re.match(r"DELTA TOTAL", line):
                dG5_total = line.split()
                dG5_list.append(dG5_total[2])
    except FileNotFoundError as e:
        print(e.filename)
        non="none"
        dG5_list.append(non)
list5c2 = pd.DataFrame({'title': title,'dG conf2': dG5_list})

# %% [markdown]
# ## Check duplicates

# %%
list1c1[list1c1.duplicated(['dG conf1'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [title, dG conf1]
# Index: []

# %%
list2c1[list2c1.duplicated(['dG conf1'], keep=False)]
# Out:
#                     title  dG conf1
# 109  ligprep_1_sdf_151137  -22.6903
# 688  ligprep_1_sdf_175334  -22.6903

# %%
list3c1[list3c1.duplicated(['dG conf1'], keep=False)]
# Out:
#                     title  dG conf1
# 33   ligprep_1_sdf_196923  -27.0443
# 726   ligprep_1_sdf_35440  -27.0443

# %%
list4c1[list4c1.duplicated(['dG conf1'], keep=False)]
# Out:
#                    title  dG conf1
# 618  ligprep_1_sdf_70883  -29.8092
# 858  ligprep_1_sdf_76134  -29.8092

# %%
list5c1[list5c1.duplicated(['dG conf1'], keep=False)]
# Out:
#                    title  dG conf1
# 90   ligprep_1_sdf_81705  -26.1590
# 170   ligprep_1_sdf_8465  -26.1590

# %%
list1c2[list1c2.duplicated(['dG conf2'], keep=False)]
# Out:
#                     title  dG conf2
# 3     ligprep_1_sdf_39772  -32.9641
# 4     ligprep_1_sdf_39667  -32.4332
# 6     ligprep_1_sdf_39772  -32.9641
# 9     ligprep_1_sdf_39667  -32.4332
# 12   ligprep_1_sdf_127608   -9.4268
# ..                    ...       ...
# 960    ligprep_1_sdf_2175  -22.7579
# 962  ligprep_1_sdf_162947  -23.7733
# 966   ligprep_1_sdf_55879  -24.4675
# 979   ligprep_1_sdf_71167  -22.7335
# 982   ligprep_1_sdf_55879  -24.4675
#
# [84 rows x 2 columns]

# %%
list2c2[list2c2.duplicated(['dG conf2'], keep=False)]
# Out:
#                     title  dG conf2
# 11   ligprep_1_sdf_201849  -24.7306
# 24    ligprep_1_sdf_55879  -24.4675
# 39    ligprep_1_sdf_40445  -39.5536
# 59    ligprep_1_sdf_40445  -39.5536
# 87    ligprep_1_sdf_65936  -34.6893
# 110   ligprep_1_sdf_49341  -20.7609
# 120   ligprep_1_sdf_55879  -24.4675
# 138  ligprep_1_sdf_185364  -20.7943
# 157  ligprep_1_sdf_105948  -19.2081
# 160  ligprep_1_sdf_170465  -21.4270
# 171  ligprep_1_sdf_201849  -24.7306
# 204  ligprep_1_sdf_207544  -18.2328
# 210   ligprep_1_sdf_65936  -34.6893
# 217    ligprep_1_sdf_2742  -19.3109
# 232   ligprep_1_sdf_50009  -31.0896
# 267   ligprep_1_sdf_39468  -20.5770
# 275   ligprep_1_sdf_36172  -22.0785
# 317  ligprep_1_sdf_150984  -30.1625
# 325   ligprep_1_sdf_39468  -20.5770
# 329   ligprep_1_sdf_48410  -23.0847
# 330   ligprep_1_sdf_39468  -20.5770
# 381   ligprep_1_sdf_65054  -27.3496
# 397  ligprep_1_sdf_170160  -27.5726
# 415  ligprep_1_sdf_110250  -17.1087
# 418   ligprep_1_sdf_56176  -26.6921
# ...

# %%
list3c2[list3c2.duplicated(['dG conf2'], keep=False)]
# Out:
#                     title  dG conf2
# 13    ligprep_1_sdf_16998  -22.4349
# 20    ligprep_1_sdf_55879  -24.4675
# 35   ligprep_1_sdf_105906  -19.6839
# 63    ligprep_1_sdf_55879  -24.4675
# 103  ligprep_1_sdf_199702  -12.1198
# 133   ligprep_1_sdf_39468  -20.5770
# 148  ligprep_1_sdf_185788  -28.1583
# 152   ligprep_1_sdf_39468  -20.5770
# 235  ligprep_1_sdf_185788  -28.1583
# 268   ligprep_1_sdf_75073  -18.4886
# 308   ligprep_1_sdf_48410  -23.0847
# 313    ligprep_1_sdf_2742  -19.3109
# 319   ligprep_1_sdf_50006  -25.3848
# 320  ligprep_1_sdf_105906  -19.6839
# 327  ligprep_1_sdf_158572  -27.2891
# 342   ligprep_1_sdf_48410  -23.0847
# 384  ligprep_1_sdf_104213   -8.1014
# 388   ligprep_1_sdf_36172  -22.0785
# 454    ligprep_1_sdf_2742  -19.3109
# 466   ligprep_1_sdf_36172  -22.0785
# 502    ligprep_1_sdf_1806  -13.5448
# 512    ligprep_1_sdf_2742  -19.3109
# 537   ligprep_1_sdf_42330  -28.1021
# 601   ligprep_1_sdf_16998  -22.4349
# 623  ligprep_1_sdf_155492  -33.0664
# ...

# %%
list4c2[list4c2.duplicated(['dG conf2'], keep=False)]
# Out:
#                     title  dG conf2
# 4    ligprep_1_sdf_199726  -23.0211
# 20    ligprep_1_sdf_49365  -28.6016
# 30    ligprep_1_sdf_40372  -32.0217
# 60    ligprep_1_sdf_40319  -34.1400
# 64    ligprep_1_sdf_75369  -30.3587
# 132   ligprep_1_sdf_40419  -35.1687
# 255   ligprep_1_sdf_80162  -21.8255
# 256   ligprep_1_sdf_50003  -21.6826
# 290  ligprep_1_sdf_151926  -28.3031
# 301   ligprep_1_sdf_14100  -20.8756
# 314   ligprep_1_sdf_62042  -24.0768
# 326  ligprep_1_sdf_105913  -22.9054
# 368  ligprep_1_sdf_199726  -23.0211
# 378  ligprep_1_sdf_101289  -11.2920
# 401   ligprep_1_sdf_40372  -32.0217
# 408   ligprep_1_sdf_80162  -21.8255
# 415  ligprep_1_sdf_191860  -30.8091
# 475   ligprep_1_sdf_12378  -24.7406
# 480   ligprep_1_sdf_40319  -34.1400
# 483  ligprep_1_sdf_105913  -22.9054
# 552   ligprep_1_sdf_43097  -32.3844
# 556   ligprep_1_sdf_10078  -30.8091
# 564   ligprep_1_sdf_49365  -28.6016
# 576  ligprep_1_sdf_151926  -28.3031
# 583   ligprep_1_sdf_87990  -19.7195
# ...

# %%
list5c2[list5c2.duplicated(['dG conf2'], keep=False)]
# Out:
#                     title  dG conf2
# 2     ligprep_1_sdf_36172  -22.0785
# 13   ligprep_1_sdf_106068  -28.3961
# 59   ligprep_1_sdf_105907  -28.1605
# 103   ligprep_1_sdf_10079  -29.5047
# 111  ligprep_1_sdf_207732   -8.0985
# 123   ligprep_1_sdf_40401  -28.1595
# 133   ligprep_1_sdf_40401  -28.1595
# 165   ligprep_1_sdf_10079  -29.5047
# 190   ligprep_1_sdf_39469  -21.9658
# 199   ligprep_1_sdf_90766  -24.7924
# 256   ligprep_1_sdf_43092  -31.3865
# 262   ligprep_1_sdf_36172  -22.0785
# 275  ligprep_1_sdf_106068  -28.3961
# 354   ligprep_1_sdf_39468  -20.5770
# 379  ligprep_1_sdf_101451  -20.7674
# 456   ligprep_1_sdf_40316  -30.9826
# 481  ligprep_1_sdf_106302  -23.1972
# 543    ligprep_1_sdf_1481  -24.2251
# 582   ligprep_1_sdf_39468  -20.5770
# 594  ligprep_1_sdf_207732   -8.0985
# 610   ligprep_1_sdf_39624  -20.0509
# 636   ligprep_1_sdf_40413  -33.3984
# 639   ligprep_1_sdf_40421  -34.7619
# 667  ligprep_1_sdf_101451  -20.7674
# 677   ligprep_1_sdf_43092  -31.3865
# ...

# %%
listc1 = pd.concat([list1c1, list2c1, list3c1, list4c1, list5c1], axis=0)
listc2 = pd.concat([list1c2, list2c2, list3c2, list4c2, list5c2], axis=0)

# %%
idNumlist=pd.read_csv("/home/chuck/u1/pde2/idnumlist.csv", header=0, sep=',', engine='python')
idNumlist['title'] = idNumlist['title'].str.replace('.','_')
idNumlist['title'] = idNumlist['title'].str.replace(':','_')
idNumlist.drop_duplicates(['IDNUMBER'], inplace=True)

# %%
allIC50=pd.read_csv("/home/chuck/ipn/PDE2/all.csv", header=0, sep=',', engine='python')
dG=pd.merge(listc1, listc2, how='outer', on='title')
dG=pd.merge(dG, idNumlist, how='left', on='title')
fin2=pd.merge(dG, allIC50, how='left', on='title')

fin2['dG conf1'] = pd.to_numeric(fin2['dG conf1'])
fin2['dG conf2'] = pd.to_numeric(fin2['dG conf2'])

fin2['Lowest'] = fin2[['dG conf1','dG conf2']].min(axis=1)
fin2.sort_values(by=['Lowest'], inplace=True)
fin2["Rank"] = fin2['Lowest'].rank(method='first')
fin2.to_csv("/home/chuck/ipn/PDE2/GBSA_XP.csv", index=False)
