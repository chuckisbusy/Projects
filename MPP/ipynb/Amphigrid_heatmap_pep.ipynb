# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = 10,10
plt.rcParams['axes.linewidth'] = 2.0
plt.rcParams['savefig.dpi'] = 500
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
def process_csv_file(csv_file):
    # Load the CSV into a pandas DataFrame
    df = pd.read_csv(csv_file, header=None, names=['ID', 'RMSD', 'z_increment', 'pert_num'])

    # Calculate average RMSD
    avg_rmsd = df['RMSD'].mean()

    # Extract z_increment and pert_num
    z_increment = df['z_increment'].iloc[0]
    pert_num = df['pert_num'].iloc[0]

    return avg_rmsd, z_increment, pert_num

# %%
def process_directories(base_dir,target_csv):
    results = []
    for subdir, _, files in os.walk(base_dir):
        if target_csv in files:
            csv_file = os.path.join(subdir, target_csv)
            avg_rmsd, z_increment, pert_num = process_csv_file(csv_file)
            if avg_rmsd is not None:
                results.append([subdir, avg_rmsd, z_increment, pert_num])
    
    # Convert the results to a pandas DataFrame
    return pd.DataFrame(results, columns=['Directory', 'Average_RMSD', 'z_increment', 'pert_num'])

# %% [markdown]
# ## Analyze Results.1

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.1/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)

# %%
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g')

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmappep1.png", format='png', transparent=True, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g')
#       3 plt.xlabel("Z increments", fontsize = 20)
#       4 plt.ylabel("# of Perturbations", fontsize = 20)
#
# File ~/.local/lib/python3.11/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File ~/.local/lib/python3.11/site-packages/seaborn/matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File ~/.local/lib/python3.11/site-packages/seaborn/matrix.py:202, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     200         vmin = np.nanpercentile(calc_data, 2)
#     201     else:
# --> 202         vmin = np.nanmin(calc_data)
#     203 if vmax is None:
#     204     if robust:
#
# File ~/.local/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:361, in nanmin(a, axis, out, keepdims, initial, where)
#     356     kwargs['where'] = where
#     358 if type(a) is np.ndarray and a.dtype != np.object_:
#     359     # Fast, but not safe for subclasses of ndarray, or object arrays,
#     360     # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 361     res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     362     if np.isnan(res).any():
#     363         warnings.warn("All-NaN slice encountered", RuntimeWarning,
#     364                       stacklevel=2)
#
# ValueError: zero-size array to reduction operation fmin which has no identity

# %% [markdown]
# ## Analyze Results.2

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.2/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)

# %%
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g')

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmappep2.png", format='png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ## Analyze Results.3

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.3/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)

# %%
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g')

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmappep3.png", format='png', transparent=True, bbox_inches='tight')
