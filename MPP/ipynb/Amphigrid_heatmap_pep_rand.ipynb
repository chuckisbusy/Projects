# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = 10,10
plt.rcParams['axes.linewidth'] = 2.0
plt.rcParams['savefig.dpi'] = 500
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
def process_csv_file(csv_file):
    # Load the CSV into a pandas DataFrame
    df = pd.read_csv(csv_file, header=None, names=['ID', 'RMSD', 'z_increment', 'pert_num'])

    # Calculate average RMSD
    avg_rmsd = df['RMSD'].mean()

    # Extract z_increment and pert_num
    z_increment = df['z_increment'].iloc[0]
    pert_num = df['pert_num'].iloc[0]

    return avg_rmsd, z_increment, pert_num

# %%
def process_directories(base_dir,target_csv):
    results = []
    for subdir, _, files in os.walk(base_dir):
        if target_csv in files:
            csv_file = os.path.join(subdir, target_csv)
            avg_rmsd, z_increment, pert_num = process_csv_file(csv_file)
            if avg_rmsd is not None:
                results.append([subdir, avg_rmsd, z_increment, pert_num])
    
    # Convert the results to a pandas DataFrame
    return pd.DataFrame(results, columns=['Directory', 'Average_RMSD', 'z_increment', 'pert_num'])

# %% [markdown]
# ## Analyze Results.1

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.1/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)

# %%
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g', vmin=6, vmax=9.5)

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmaprand1.png", format='png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ## Analyze Results.2

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.2/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)

# %%
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g', vmin=6, vmax=9.5)

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmaprand2.png", format='png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ## Analyze Results.3

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.3/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)

# %%
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g', vmin=6, vmax=9.5)

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmaprand3.png", format='png', transparent=True, bbox_inches='tight')

# %% [markdown]
# # Analyze Grid with MHM

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.mhm/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g', vmin=6, vmax=9.5)

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmaprandmhm.png", format='png', transparent=True, bbox_inches='tight')

# %% [markdown]
# # Analyze Grid with added RigidBodyRandomize

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.rand/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g', vmin=6, vmax=9.5)

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmaprandrand.png", format='png', transparent=True, bbox_inches='tight')

# %% [markdown]
# # Analyze Grid with added WholebodyRotation

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.rot/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g', vmin=6, vmax=9.5)

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmaprandrot.png", format='png', transparent=True, bbox_inches='tight')

# %% [markdown]
# # Analyze Grid with added RigidBodySpin

# %%
os.chdir("/home/cadeniran/u1/amphiscan-pep-rand")
base_dir = "results_grid.spin/"  # Specify the base directory
output_file = "rmsd_results.csv"  # Output CSV file
target_csv = "rmsd_values.csv" #csv to look for in each subdir

# %%
data = []
data = process_directories(base_dir,target_csv)
datamap = data.pivot(index="pert_num", columns="z_increment", values="Average_RMSD")

# %%
sns.heatmap(datamap, annot=True, linewidth=2, cmap="coolwarm", annot_kws={"fontsize":11},fmt='.3g', vmin=6, vmax=9.5)

plt.xlabel("Z increments", fontsize = 20)
plt.ylabel("# of Perturbations", fontsize = 20)
plt.yticks(rotation=0)
plt.tick_params(axis='both', labelsize='15', length=2, width=2)
plt.savefig("/home/cadeniran/ipn/figs/heatmaprandspin.png", format='png', transparent=True, bbox_inches='tight')
