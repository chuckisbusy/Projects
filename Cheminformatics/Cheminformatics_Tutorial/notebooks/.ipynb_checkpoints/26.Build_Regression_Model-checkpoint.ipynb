# %% [markdown]
# ## Building a Simple Regression Model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
from tqdm.auto import tqdm
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from lightgbm import LGBMRegressor, plot_importance
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error #ML stats
from yellowbrick.regressor import prediction_error, ResidualsPlot
from tdc.single_pred import ADME

# %%
plt.rcParams['figure.figsize'] = 7,7
plt.rcParams['axes.linewidth'] = 2.0
plt.rcParams['savefig.dpi'] = 500
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = ['DeJavu Serif']
plt.rcParams['font.serif'] = ['Times New Roman']
sns.set_context('talk')
np.set_printoptions(legacy='1.25')

# %% [markdown]
# Enable Pandas progress_apply

# %%
tqdm.pandas()

# %% [markdown]
# Read the data

# %%
data = ADME(name = 'Solubility_AqSolDB')
sol_df = data.get_data()
sol_df.columns = ["Name","SMILES","LogS"]
# Out:
# Found local copy...
# Loading...
# Done!

# %% [markdown]
# Set up property calculations

# %%
property_names = list(rdMolDescriptors.Properties.GetAvailableProperties())
property_getter = rdMolDescriptors.Properties(property_names)

# %% [markdown]
# Define a function to calculate properties from SMILES

# %%
def smi2props(smi):
    mol = Chem.MolFromSmiles(smi)
    props = None
    if mol:
        Chem.DeleteSubstructs(mol, Chem.MolFromSmarts("[#1X0]"))
        props = np.array(property_getter.ComputeProperties(mol))
    return props

# %% [markdown]
# Add the properties to the dataframe

# %%
sol_df['props'] = sol_df.SMILES.progress_apply(smi2props)
# Out:
#   0%|          | 0/9982 [00:00<?, ?it/s]
# [17:47:30] WARNING: not removing hydrogen atom without neighbors
# [17:47:30] WARNING: not removing hydrogen atom without neighbors
# [17:47:30] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:31] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:32] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:33] WARNING: not removing hydrogen atom without neighbors
# [17:47:34] WARNING: not removing hydrogen atom without neighbors
# [17:47:34] WARNING: not removing hydrogen atom without neighbors
# [17:47:34] WARNING: not removing hydrogen atom without neighbors
# [17:47:35] WARNING: not removing hydrogen atom without neighbors
# [17:47:35] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# Put the descriptors into individual columns

# %%
sol_df[property_names] = sol_df['props'].to_list()

# %% [markdown]
# Split the data into training and test sets

# %%
train, test = train_test_split(sol_df)

# %% [markdown]
# Define x and y variables for model building

# %%
train_X = train[property_names]
train_y = train.LogS
test_X = test[property_names]
test_y = test.LogS

# %% [markdown]
# Create a LightGBM Repressor

# %%
lgbm = LGBMRegressor()

# %% [markdown]
# Fit the model

# %%
lgbm.fit(train_X, train_y)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000883 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6071
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.880369
# LGBMRegressor()

# %% [markdown]
# Make the prediction

# %%
pred = lgbm.predict(test_X)

# %% [markdown]
# Plot predicted vs experimental solubility

# %%
ax = sns.scatterplot(x=test_y,y=pred)
ax.set(xlabel="Experimental LogS")
ax.set(ylabel="Predicted LogS")
# Out:
# [Text(0, 0.5, 'Predicted LogS')]

# %% [markdown]
# Make the same plot with Seaborn's **regplot**

# %%
ax = sns.regplot(x=test_y,y=pred,scatter_kws={'s':10})
ax.set(xlabel="Experimental LogS")
ax.set(ylabel="Predicted LogS")
# Out:
# [Text(0, 0.5, 'Predicted LogS')]

# %% [markdown]
# Calculate the coeffcient of determination (R<sup>2</sup>)

# %%
r2_score(test_y,pred)
# Out:
# 0.7823707841599902

# %% [markdown]
# Calculate the RMS error

# %%
mean_squared_error(test_y,pred,squared=False)
# Out:
# 1.1202570721924647

# %% [markdown]
# LightGBM provides an easy means of identifying important variables

# %%
plot_importance(lgbm,figsize=(8,12),height=0.5)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# The [Yellowbrick](https://www.scikit-yb.org/en/latest/index.html) Python library provides some useful diagnostic plots for ML models.

# %%
lgbm = LGBMRegressor()
train, test = train_test_split(sol_df)
train_X = train[property_names]
train_y = train.LogS
test_X = test[property_names]
test_y = test.LogS

# %%
visualizer = prediction_error(lgbm, train_X, train_y, test_X, test_y,alpha=0.35)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6082
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.880187

# %%
visualizer = ResidualsPlot(lgbm)
visualizer.fit(train_X, train_y)
visualizer.score(test_X, test_y)
visualizer.show();

# %% [markdown]
# Run 10 cycles of cross validation on a model

# %%
r2_list = []
for i in tqdm(range(0,10)):
    # setup training and test sets
    train, test = train_test_split(sol_df)
    train_X = train[property_names]
    train_y = train.LogS
    test_X = test[property_names]
    test_y = test.LogS
    # create the regressor
    lgbm = LGBMRegressor()
    # train the model
    lgbm.fit(train_X,train_y)
    pred = lgbm.predict(test_X)
    r2 = r2_score(test_y,pred)
    print(r2)
    r2_list.append(r2)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001016 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6086
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.898317
# 0.7823253099983228
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000833 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6078
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.877047
# 0.7783490668402702
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001156 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6084
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.888901
# 0.7882814276931649
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6070
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.862076
# 0.7433496564389518
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6090
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.884977
# 0.7776144434843261
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6082
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.914135
# 0.7868927813198957
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6082
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.892622
# 0.7542046462416648
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001174 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6064
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.907253
# 0.7848890896816674
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6088
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.866958
# 0.7716687747142307
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001032 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6085
# [LightGBM] [Info] Number of data points in the train set: 7486, number of used features: 43
# [LightGBM] [Info] Start training from score -2.914526
# 0.7824485926089958

# %% [markdown]
# Plot R<sup>2</sup> across the 10 folds as a boxplot

# %%
ax = sns.boxplot(x=r2_list)
ax.set(xlim=(0,1))
ax.set(xlabel="R$^2$")
# Out:
# [Text(0.5, 0, 'R$^2$')]
