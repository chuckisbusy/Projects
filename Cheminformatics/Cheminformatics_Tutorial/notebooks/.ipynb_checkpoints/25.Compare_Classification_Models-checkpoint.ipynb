# %% [markdown]
# ### Comparing Classification Models
# In this tutorial we'll discuss a few methods for comparing classification models.  For more of a discussion of this topic see this [blog post](http://practicalcheminformatics.blogspot.com/2020/05/some-thoughts-on-comparing.html).

# %%
import requests
import os
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np
import scikit_posthocs as sp
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from rdkit import Chem
from mlxtend.evaluate import cochrans_q, mcnemar, mcnemar_table
from tqdm.notebook import tqdm
from itertools import combinations
from delong_ci import calc_auc_ci
from scipy.stats import wilcoxon
from mlxtend.evaluate import paired_ttest_5x2cv
from bootstrap import bootstrap_error_estimate
from scipy import stats
from tqdm.auto import tqdm
from rdkit import DataStructs
from rdkit.Chem import rdFingerprintGenerator

# %%
plt.rcParams['figure.figsize'] = 7,7
plt.rcParams['axes.linewidth'] = 2.0
plt.rcParams['savefig.dpi'] = 500
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = ['DeJavu Serif']
plt.rcParams['font.serif'] = ['Times New Roman']
sns.set(font_scale=1.5)
sns.set_style('whitegrid')
#pd.set_option('precision', 2)
pd.set_option('display.precision', 2)

# %%
def mol2morgan_fp(mol, radius: int = 2, fpSize: int = 2048) -> DataStructs.ExplicitBitVect:
    """Convert an RDKit molecule to a Morgan fingerprint

    :param mol: RDKit molecule
    :param radius: fingerprint radius
    :param nBits: number of fingerprint bits
    :return: RDKit Morgan fingerprint
    """

    fpgen = rdFingerprintGenerator.GetMorganGenerator(radius=radius, fpSize=fpSize)
    fp = fpgen.GetFingerprint(mol)
    return fp

# %%
tqdm.pandas()

# %% [markdown]
# #### Read the Input Data
# Read the data

# %%
file = "../data/chembl_herg_log_activity.csv"
df = pd.read_csv(file)

# %%
df.head()
# Out:
#                                               smiles  pIC50
# 0     Brc1cc(CCN2CCN(CCc3ccc4C(=O)OCc4c3)CC2)ccc1C#N   6.25
# 1   Brc1ccc(CNC(=O)C2N(CCc3ccccn3)C(=O)c4ccccc24)cc1   5.03
# 2  Brc1ccc(NC(=O)N2CCN(C[C@@H]3CCCN(C3)C4CC4)CC2)cc1   5.15
# 3    Brc1ccc(cc1)N(C2CCN(CC2)C3CCCC3)C(=O)NCc4ccccc4   6.75
# 4     Brc1ccc(cc1)N(C2CCN(CC2)C3CCCC3)C(=O)Nc4ccccc4   6.73

# %% [markdown]
# Plot the data distribution

# %%
sns.displot(df.pIC50);

# %% [markdown]
# #### Assign Labels for Classification
# Label the molecules with IC50 <- 1uM (pIC >= 6) as active

# %%
df['active'] = [int(x >= 6) for x in df.pIC50]

# %%
df.head()
# Out:
#                                               smiles  pIC50  active
# 0     Brc1cc(CCN2CCN(CCc3ccc4C(=O)OCc4c3)CC2)ccc1C#N   6.25       1
# 1   Brc1ccc(CNC(=O)C2N(CCc3ccccn3)C(=O)c4ccccc24)cc1   5.03       0
# 2  Brc1ccc(NC(=O)N2CCN(C[C@@H]3CCCN(C3)C4CC4)CC2)cc1   5.15       0
# 3    Brc1ccc(cc1)N(C2CCN(CC2)C3CCCC3)C(=O)NCc4ccccc4   6.75       1
# 4     Brc1ccc(cc1)N(C2CCN(CC2)C3CCCC3)C(=O)Nc4ccccc4   6.73       1

# %% [markdown]
# #### Add Descriptors

# %%
df['mol'] = df.smiles.progress_apply(Chem.MolFromSmiles)
# Out:
#   0%|          | 0/5691 [00:00<?, ?it/s]

# %% [markdown]
# Add Morgan fingerprints

# %%
df['fp'] = df.mol.progress_apply(mol2morgan_fp)
# Out:
#   0%|          | 0/5691 [00:00<?, ?it/s]

# %% [markdown]
# #### Cross-Validate Models
# In this code block, we generate three different classification models, an Extreme Gradient Boosting (XGBoost) classifier, a Random Forest classifier, and a Light Gradient Boosting Machine (LightGBM) classifier. We then perform 10 folds of cross-validation with each classier, using the same training and test sets in each fold.

# %%
method_list = [XGBClassifier, RandomForestClassifier, LGBMClassifier]
method_name_list = [x().__class__.__name__ for x in method_list]
method_name_list = [x.replace("Classifier","") for x in method_name_list]
truth_list = []
pred_list = []
prob_list = []
cv_cycles = 10
for i in tqdm(range(0,cv_cycles)):
    train, test = train_test_split(df)
    train_X = np.stack(train.fp)
    train_y = train.active.values
    test_X = np.stack(test.fp)
    test_y = test.active.values
    cycle_pred = []
    cycle_prob = []
    for method in method_list:
        cls = method(n_jobs=-1)
        cls.fit(train_X,train_y)
        cycle_pred.append(cls.predict(test_X))
        cycle_prob.append(cls.predict_proba(test_X))
        
    truth_list.append(test.active.values)        
    pred_list.append(cycle_pred)
    prob_list.append(cycle_prob)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 857, number of negative: 3411
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 4.047649 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3134
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1567
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.200797 -> initscore=-1.381323
# [LightGBM] [Info] Start training from score -1.381323
# [LightGBM] [Info] Number of positive: 869, number of negative: 3399
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020810 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3130
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1565
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.203608 -> initscore=-1.363893
# [LightGBM] [Info] Start training from score -1.363893
# [LightGBM] [Info] Number of positive: 889, number of negative: 3379
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 1.467827 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3130
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1565
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.208294 -> initscore=-1.335238
# [LightGBM] [Info] Start training from score -1.335238
# [LightGBM] [Info] Number of positive: 859, number of negative: 3409
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.095070 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3132
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1566
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.201265 -> initscore=-1.378405
# [LightGBM] [Info] Start training from score -1.378405
# [LightGBM] [Info] Number of positive: 873, number of negative: 3395
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013558 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3152
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1576
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.204545 -> initscore=-1.358123
# [LightGBM] [Info] Start training from score -1.358123
# [LightGBM] [Info] Number of positive: 874, number of negative: 3394
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013911 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3148
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1574
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.204780 -> initscore=-1.356684
# [LightGBM] [Info] Start training from score -1.356684
# [LightGBM] [Info] Number of positive: 865, number of negative: 3403
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014197 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3126
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1563
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202671 -> initscore=-1.369683
# [LightGBM] [Info] Start training from score -1.369683
# [LightGBM] [Info] Number of positive: 866, number of negative: 3402
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 1.616293 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3098
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1549
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202905 -> initscore=-1.368234
# [LightGBM] [Info] Start training from score -1.368234
# [LightGBM] [Info] Number of positive: 852, number of negative: 3416
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3156
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1578
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.199625 -> initscore=-1.388639
# [LightGBM] [Info] Start training from score -1.388639
# [LightGBM] [Info] Number of positive: 885, number of negative: 3383
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 2.544004 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3144
# [LightGBM] [Info] Number of data points in the train set: 4268, number of used features: 1572
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.207357 -> initscore=-1.340931
# [LightGBM] [Info] Start training from score -1.340931

# %% [markdown]
# #### Evaluate Models
# In order to compare the performance of the models, we will calculate the Area Under the Receiver Opererating Characteristic (AUC) for each model in each fold.

# %%
auc_result = []
for truth, prob in zip(truth_list,prob_list):
    for name, p in zip(method_name_list, prob):
        auc_result.append([name,roc_auc_score(truth,p[:,1])])
auc_df = pd.DataFrame(auc_result,columns=["Method","AUC"])

# %% [markdown]
# #### Some "Wrong" Ways to Compare Classification Models
# Most papers I see show barplots with "whisker" showing the standard deviation for multiple replicates. **Please don't do this**

# %%
my_pal = {"XGB": "g", "RandomForest": "b", "LGBM":"m"}
ax = sns.barplot(x="Method",y="AUC",data=auc_df,palette=my_pal, hue=auc_df["Method"])
labels = [x.get_text() for x in ax.get_xticklabels()]

# %% [markdown]
# An alternate and still less than correct, approach is to plot the replicates as box plots.

# %%
ax = sns.boxplot(y="Method",x="AUC",data=auc_df,notch=True, palette=my_pal, hue=auc_df["Method"])

# %% [markdown]
# #### 1. Confidence Intervals for AUC
# Use DeLong's method to calculate the confidence interval for an AUC

# %%
auc_result = []
for cycle, [truth, prob] in enumerate(zip(truth_list,prob_list)):
    for name, p in zip(method_name_list, prob):
        truth = np.array([int(x) for x in truth])
        auc, (lb, ub) = calc_auc_ci(truth,p[:,1])
        auc_result.append([cycle,name, auc, lb, ub])
auc_ci_df = pd.DataFrame(auc_result,columns=["Cycle","Method","AUC","LB","UB"])
auc_ci_df.head()
# Out:
#    Cycle        Method   AUC    LB    UB
# 0      0           XGB  0.86  0.83  0.88
# 1      0  RandomForest  0.86  0.83  0.88
# 2      0          LGBM  0.87  0.85  0.89
# 3      1           XGB  0.84  0.82  0.87
# 4      1  RandomForest  0.86  0.83  0.88

# %%
sns.set(rc={'figure.figsize': (14, 7)})
sns.set(font_scale=1.5)
sns.set_style('white')

# %% [markdown]
# Define a routine to plot the confidence interval for the AUC.

# %%
def ci_pointplot(input_df, x_col="Cycle", y_col="AUC", hue_col="Method", lb_col="LB", ub_col="UB"):
    dodge_val = 0.25
    palette_name = "deep"
    cv_cycles = len(input_df[x_col].unique())
    ax = sns.pointplot(x=x_col, y=y_col, hue=hue_col, data=input_df, dodge=dodge_val, linestyle='none', palette=palette_name)
    ax.axvline(0.5, ls="--", c="gray")
    for x in np.arange(0.5, cv_cycles, 1):
        ax.axvline(x, ls="--", c="gray")
    y_val = input_df[y_col]
    lb = y_val - input_df[lb_col]
    ub = input_df[ub_col] - y_val
    x_pos = []
    cols = sns.color_palette(palette_name)[:3]
    for i in range(0, cv_cycles):
        x_pos += [i - dodge_val / 2, i, i + dodge_val / 2]
    _ = ax.errorbar(x_pos, y_val, yerr=[lb, ub], fmt="none", capsize=0,ecolor=cols)

# %%
ci_pointplot(auc_ci_df)

# %% [markdown]
# #### 2. Bootstrap an Error Estimate

# %%
bootstrap_result = []
with tqdm(total=len(truth_list)) as pbar:
    for cycle,[truth,probs] in enumerate(zip(truth_list,prob_list)):
        for name,p in zip(method_name_list,probs):
            auc = roc_auc_score(truth,p[:,1])
            lb,ub = bootstrap_error_estimate(truth,p[:,1],roc_auc_score)
            bootstrap_result.append([cycle,name,auc,lb,ub])
        pbar.update(1)
bootstrap_df = pd.DataFrame(bootstrap_result,columns=["Cycle","Method","AUC","LB","UB"])
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
ci_pointplot(bootstrap_df)

# %% [markdown]
# #### 3. 5x2-fold cross validation

# %%
X = np.stack(df.fp)
y = df.active.values
classifier_list = [x(n_jobs=-1) for x in method_list]
print(f"{'Method_1':12s} {'Method_2':12s} {'p-value'}")
for a,b in combinations(zip(classifier_list,method_name_list),2):
    clf1,name1 = a
    clf2,name2 = b
    t, p = paired_ttest_5x2cv(estimator1=clf1,estimator2=clf2,X=X, y=y, scoring="roc_auc")
    print(f"{name1:12s} {name2:12s} {p:.3f}")
# Out:
# Method_1     Method_2     p-value
# XGB          RandomForest 0.029
# [LightGBM] [Info] Number of positive: 583, number of negative: 2262
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012088 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2574
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1287
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.204921 -> initscore=-1.355817
# [LightGBM] [Info] Start training from score -1.355817
# [LightGBM] [Info] Number of positive: 582, number of negative: 2264
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012489 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2596
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1298
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.204498 -> initscore=-1.358418
# [LightGBM] [Info] Start training from score -1.358418
# [LightGBM] [Info] Number of positive: 577, number of negative: 2268
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 1.154707 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2612
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1306
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202812 -> initscore=-1.368811
# [LightGBM] [Info] Start training from score -1.368811
# [LightGBM] [Info] Number of positive: 588, number of negative: 2258
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 2.949836 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2582
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1291
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206606 -> initscore=-1.345508
# [LightGBM] [Info] Start training from score -1.345508
# [LightGBM] [Info] Number of positive: 570, number of negative: 2275
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.086906 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2568
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1284
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.200351 -> initscore=-1.384099
# [LightGBM] [Info] Start training from score -1.384099
# [LightGBM] [Info] Number of positive: 595, number of negative: 2251
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012785 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2602
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1301
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.209065 -> initscore=-1.330568
# [LightGBM] [Info] Start training from score -1.330568
# [LightGBM] [Info] Number of positive: 574, number of negative: 2271
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012106 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2588
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1294
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.201757 -> initscore=-1.375346
# [LightGBM] [Info] Start training from score -1.375346
# [LightGBM] [Info] Number of positive: 591, number of negative: 2255
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 2.098110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2584
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1292
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.207660 -> initscore=-1.339089
# [LightGBM] [Info] Start training from score -1.339089
# [LightGBM] [Info] Number of positive: 614, number of negative: 2231
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 1.801458 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2634
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1317
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.215817 -> initscore=-1.290210
# [LightGBM] [Info] Start training from score -1.290210
# [LightGBM] [Info] Number of positive: 551, number of negative: 2295
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013294 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2564
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1282
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.193605 -> initscore=-1.426753
# [LightGBM] [Info] Start training from score -1.426753
# XGB          LGBM         0.034
# [LightGBM] [Info] Number of positive: 590, number of negative: 2255
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011705 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2600
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1300
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.207381 -> initscore=-1.340783
# [LightGBM] [Info] Start training from score -1.340783
# [LightGBM] [Info] Number of positive: 575, number of negative: 2271
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.059022 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2594
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1297
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.202038 -> initscore=-1.373606
# [LightGBM] [Info] Start training from score -1.373606
# [LightGBM] [Info] Number of positive: 560, number of negative: 2285
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2576
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1288
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.196837 -> initscore=-1.406185
# [LightGBM] [Info] Start training from score -1.406185
# [LightGBM] [Info] Number of positive: 605, number of negative: 2241
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012794 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2600
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1300
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.212579 -> initscore=-1.309449
# [LightGBM] [Info] Start training from score -1.309449
# [LightGBM] [Info] Number of positive: 579, number of negative: 2266
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012820 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2580
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1290
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.203515 -> initscore=-1.364469
# [LightGBM] [Info] Start training from score -1.364469
# [LightGBM] [Info] Number of positive: 586, number of negative: 2260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.041106 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2598
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1299
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205903 -> initscore=-1.349800
# [LightGBM] [Info] Start training from score -1.349800
# [LightGBM] [Info] Number of positive: 559, number of negative: 2286
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011803 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2582
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1291
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.196485 -> initscore=-1.408409
# [LightGBM] [Info] Start training from score -1.408409
# [LightGBM] [Info] Number of positive: 606, number of negative: 2240
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013632 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2572
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1286
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.212930 -> initscore=-1.307351
# [LightGBM] [Info] Start training from score -1.307351
# [LightGBM] [Info] Number of positive: 578, number of negative: 2267
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013477 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2630
# [LightGBM] [Info] Number of data points in the train set: 2845, number of used features: 1315
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.203163 -> initscore=-1.366639
# [LightGBM] [Info] Start training from score -1.366639
# [LightGBM] [Info] Number of positive: 587, number of negative: 2259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.044476 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2556
# [LightGBM] [Info] Number of data points in the train set: 2846, number of used features: 1278
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206254 -> initscore=-1.347653
# [LightGBM] [Info] Start training from score -1.347653
# RandomForest LGBM         0.183

# %% [markdown]
# #### 4. McNemar's Test

# %%
mc_result = []
for truth, pred in zip(truth_list,pred_list): 
    for i,j in combinations(range(len(method_list)),2):
        mc, mc_pvalue = mcnemar(mcnemar_table(truth, pred[i], pred[j]))
        mc_result.append([method_name_list[i],method_name_list[j], mc_pvalue])
mc_df = pd.DataFrame(mc_result,columns=["Method_1","Method_2","p_value"])
mc_df['Combo'] = mc_df.Method_1 + "_" + mc_df.Method_2
mc_df.head()
# Out:
#        Method_1      Method_2  p_value              Combo
# 0           XGB  RandomForest     0.03   XGB_RandomForest
# 1           XGB          LGBM     1.00           XGB_LGBM
# 2  RandomForest          LGBM     0.08  RandomForest_LGBM
# 3           XGB  RandomForest     0.25   XGB_RandomForest
# 4           XGB          LGBM     0.24           XGB_LGBM

# %% [markdown]
# #### 5. Account for Multiple Testing
# Calculate the Bonferroni correction for the p-value that will be considered significant.

# %%
alpha = 0.05/len(pred_list[0])
alpha
# Out:
# 0.016666666666666666

# %% [markdown]
# Generate a boxplot of with the p-value for the McNemar coefficient for each pair of comparisons

# %%
sns.set(rc={'figure.figsize': (14, 7)})
sns.set(font_scale=1.5)
sns.set_style('whitegrid')

# %%
ax = sns.boxplot(x="p_value",y="Combo",data=mc_df, hue="Combo")
ax.set(ylabel="",xlabel="p value")
_ = ax.axvline(alpha,c="red",ls="--")

# %% [markdown]
# #### 6. Friedman's Test with Mann-Whitney Post-hoc
#
# We can't do ANOVA because our samples are not independent

# %%
auc_dict = {}
for k,v in auc_ci_df.groupby("Method"):
    auc_dict[k] = v.AUC
stats.friedmanchisquare(*auc_dict.values())
# Out:
# FriedmanchisquareResult(statistic=np.float64(12.200000000000017), pvalue=np.float64(0.0022428677194857843))

# %%
sns.set(rc={'figure.figsize':(8,6)},font_scale=1.5)
pc = sp.posthoc_mannwhitney(auc_ci_df,val_col="AUC",group_col="Method",p_adjust='holm')
heatmap_args = {'linewidths': 0.25, 'linecolor': '0.5', 'clip_on': False, 'square': True, 'cbar_ax_bbox': [0.80, 0.35, 0.04, 0.3]}
_ = sp.sign_plot(pc, **heatmap_args)
