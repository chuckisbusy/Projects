# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import rcParams
# %matplotlib inline

# %%
rcParams['figure.figsize'] = 10,10
rcParams['axes.linewidth'] = 4.0
rcParams['savefig.dpi'] = 500
rcParams['pdf.fonttype'] = 42
rcParams['ps.fonttype'] = 42
rcParams['agg.path.chunksize'] = 10000

# %% [markdown]
# # NET Distances

# %%
def calcStats (data):
    avg=np.average(data)
    std=np.std(data, dtype=np.float64)
    result = avg, u"\u00B1", std
    print('The average Dist is:', result)
    #return result
    minVal = data[data > .01].min(axis=0)
    maxVal = data.max()
    print("Range of Dist is ", minVal, "-", maxVal)

def HBondCutoff (data, cutoffTemp):    
    allLen = len(data)
    cutoff=(cutoffTemp + .1)
    t = list(filter((cutoff).__ge__, data))
    lenVar = len(t)
    percent = (lenVar/allLen * 100)
    print("Percentage for a", cutoffTemp ,"\u212B cuttoff is: ", percent,"%")

# %%
flist=['/mnt/u1/NET/new-net/model-2481/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-1493/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-1076/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-0685/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-1649/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-1870/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-2138/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-2440/ptraj/dist.y414N-m546OH.out',
'/mnt/u1/NET/new-net/model-2455/ptraj/dist.y414N-m546OH.out']

# %%
dist=[]
for file in flist:
    data=np.loadtxt(file,comments='#',usecols=1)
    dist.append(data)

# %%
x = np.arange(len(dist[0]))/500

plt.plot(x,dist[0], linewidth =2, label='Model 1')
plt.plot(x,dist[1], linewidth =2, label='Model 2')
plt.plot(x,dist[2], linewidth =2, label='Model 3')
plt.plot(x,dist[3], linewidth =2, label='Model 4')
plt.plot(x,dist[4], linewidth =2, label='Model 5')
plt.plot(x,dist[5], linewidth =2, label='Model 6')
plt.plot(x,dist[6], linewidth =2, label='Model 7')
plt.plot(x,dist[7], linewidth =2, label='Model 8')
plt.plot(x,dist[8], linewidth =2, label='Model 9')
plt.plot(x,dist[9], linewidth =2, label='Model 10', color='mediumturquoise')

leg = plt.legend(fontsize=20,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(4.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.yticks((np.arange(0, 16, step=2)), fontsize=35)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both',labelsize='38', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist1.png", transparent=True)

# %%
x = np.arange(len(dist[1]))/500

#plt.plot(x,dist[1], color='red', linewidth = 2, label='N(K88)\N{MINUS SIGN}P18 (O)')
plt.plot(x,dist[9], linewidth =1, label='Model 10', color='mediumturquoise')
plt.plot(x,dist[3], linewidth =1, label='Model 4', color='red')

leg = plt.legend(fontsize=35,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='38', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist3.png", transparent=True)

# %% [markdown]
# # Model 0204 (5)

# %%
newlist=['/mnt/u1/NET/new-net/model-0204/ptraj/dist.001.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.002.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.003.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.004.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.005.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.006.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.007.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.008.out',
'/mnt/u1/NET/new-net/model-0204/ptraj/dist.009.out']

# %%
dist1=[]
for file1 in newlist:
    data1=np.loadtxt(file1,comments='#',usecols=1)
    dist1.append(data1)

# %%
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[0], linewidth =1, label='K50N\N{MINUS SIGN}E223@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist3.png", transparent=True)

# %%
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[1], linewidth =1, label='R52@N\N{MINUS SIGN}E215@O', color='black')

leg = plt.legend(fontsize=30,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist4.png", transparent=True)

# %%
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[2], linewidth =1)

leg = plt.legend(fontsize=30,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
#plt.savefig("../../figs/dist2.png", transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
##NO BINDING D378
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[3], linewidth =1)

leg = plt.legend(fontsize=35,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time ($\mu$s)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
#plt.savefig("../../figs/dist2.png", transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
##NO BINDING D547
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[4], linewidth =1)

leg = plt.legend(fontsize=30,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time ($\mu$s)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
#plt.savefig("../../figs/dist2.png", transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[5], linewidth =1)

leg = plt.legend(fontsize=30,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
#plt.savefig("../../figs/dist2.png", transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[6], linewidth =1)

leg = plt.legend(fontsize=30,handlelength=1,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
#plt.savefig("../../figs/dist2.png", transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[7], linewidth =1, label='R56@N\N{MINUS SIGN}N198@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist5.png", transparent=True)

# %%
x = np.arange(len(dist1[1]))/500

plt.plot(x,dist1[8], linewidth =1, label='K50@N\N{MINUS SIGN}S225@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist6.png", transparent=True)

# %% [markdown]
# # Model 2455 (10)

# %%
newlist2=['/mnt/u1/NET/new-net/model-2455/ptraj/dist.0010.out',
'/mnt/u1/NET/new-net/model-2455/ptraj/dist.0011.out',
'/mnt/u1/NET/new-net/model-2455/ptraj/dist.0012.out',
'/mnt/u1/NET/new-net/model-2455/ptraj/dist.0013.out',
'/mnt/u1/NET/new-net/model-2455/ptraj/dist.0014.out']

# %%
dist2=[]
for file2 in newlist2:
    data2=np.loadtxt(file2,comments='#',usecols=1)
    dist2.append(data2)

# %%
x = np.arange(len(dist2[1]))/500

plt.plot(x,dist2[0], linewidth =1, label='R56@N\N{MINUS SIGN}N184@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
#plt.tight_layout()
plt.savefig("../../figs/dist7.png", transparent=True, bbox_inches="tight")

# %%
x = np.arange(len(dist2[1]))/500

plt.plot(x,dist2[1], linewidth =1, label='K50@N\N{MINUS SIGN}E223@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist8.png", transparent=True)

# %%
x = np.arange(len(dist2[1]))/500

plt.plot(x,dist2[2], linewidth =1)

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
#plt.savefig("../../figs/dist2.png", transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
x = np.arange(len(dist2[1]))/500

plt.plot(x,dist2[3], linewidth =1,label='R54@N\N{MINUS SIGN}N198@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist9.png", transparent=True)

# %%
x = np.arange(len(dist2[1]))/500

plt.plot(x,dist2[4], linewidth =1, label='R56@N\N{MINUS SIGN}T186@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
plt.tight_layout()
plt.savefig("../../figs/dist10.png", transparent=True)

# %% [markdown]
# # Model 4

# %%
newlist4=['/mnt/u1/NET/new-net/model-0685/ptraj/dist.015.out',
'/mnt/u1/NET/new-net/model-0685/ptraj/dist.016.out',
'/mnt/u1/NET/new-net/model-0685/ptraj/dist.017.out',
'/mnt/u1/NET/new-net/model-0685/ptraj/dist.018.out']

# %%
dist4=[]
for file4 in newlist4:
    data4=np.loadtxt(file4,comments='#',usecols=1)
    dist4.append(data4)

# %%
x = np.arange(len(dist4[1]))/500

plt.plot(x,dist4[0], linewidth =1, label='S182@\N{MINUS SIGN}R55@', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
#plt.tight_layout()
plt.savefig("../../figs/dist11.png", transparent=True, bbox_inches="tight")

# %%
x = np.arange(len(dist4[1]))/500

plt.plot(x,dist4[1], linewidth =1, label='S194@O\N{MINUS SIGN}K19@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
#plt.tight_layout()
plt.savefig("../../figs/dist12.png", transparent=True, bbox_inches="tight")

# %%
x = np.arange(len(dist4[1]))/500

plt.plot(x,dist4[2], linewidth =1, label='N184@N\N{MINUS SIGN}D5@O', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
#plt.tight_layout()
plt.savefig("../../figs/dist13.png", transparent=True, bbox_inches="tight")

# %%
x = np.arange(len(dist4[1]))/500

plt.plot(x,dist4[3], linewidth =1, label='H222@N\N{MINUS SIGN}R55@N', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
#plt.tight_layout()
plt.savefig("../../figs/dist14.png", transparent=True, bbox_inches="tight")

# %%
data1596=np.loadtxt('/mnt/u1//NET/new-net/model-2455/ptraj/dist.k596H-e170O.out',comments='#',usecols=1)

# %%
x = np.arange(len(data1596))/500

plt.plot(x,data1596, linewidth =1, label='H@K50\N{MINUS SIGN}O@E223', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
#plt.tight_layout()
plt.savefig("../../figs/dist11.png", transparent=True, bbox_inches="tight")

# %%
data600=np.loadtxt('/mnt/u1//NET/new-net/model-2455/ptraj/dist.r600H-n145O.out',comments='#',usecols=1)

# %%
x = np.arange(len(data600))/500

plt.plot(x,data600, linewidth =1, label='H@R54\N{MINUS SIGN}O@N198', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
#plt.tight_layout()
plt.savefig("../../figs/dist15.png", transparent=True, bbox_inches="tight")

# %%
data605=np.loadtxt('/mnt/u1//NET/new-net/model-2455/ptraj/dist.y414N-m546OH.out',comments='#',usecols=1)

# %%
x = np.arange(len(data605))/500

plt.plot(x,data605, linewidth =1, label='H@M1\N{MINUS SIGN}O@Y467', color='black')

leg = plt.legend(fontsize=35,handlelength=.5,loc="best")

# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(8.0)

plt.ylabel("Distance ($\AA$)", fontsize=50)
plt.xlabel("Time (ns)", fontsize=50)
plt.xticks(fontsize=35)
plt.tick_params(axis='both', labelsize='37', length=9, width=5)
#plt.tight_layout()
plt.savefig("../../figs/dist16.png", transparent=True, bbox_inches="tight")
