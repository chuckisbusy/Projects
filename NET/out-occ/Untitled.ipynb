# %%
import pandas as pd
import numpy as np

# %%
path = "/home/chuck/Workstation/projects/NET/net-oocc/pbsa"
components = ["complex","receptor","ligand"]
netoopen=dict()

for component in components:
    df = pd.read_table(path+"/energies_%s.dat"%component,sep="\s+",header=0)
    #df = df.drop(columns=['ELE'])
    netoopen[component] = df

# %%
netoopen["receptor"]
# Out:
#                 BOND      ANGLE     DIHED    VDWAAL  ELE        EPB  \
# 2125.5579  5199.4285  6063.4239  573.2902  318.6887  0.0 -4521.5888
# 2131.5706  5263.8231  5910.4996  590.3997  298.6390  0.0 -4509.5023
# 2121.5835  5160.9686  5889.1940  588.8470  320.4662  0.0 -4522.9566
# 2162.9714  5132.7700  5941.9835  597.2895  328.2941  0.0 -4483.0713
# 2098.7587  5282.9880  5906.8351  599.9389  301.6552  0.0 -4518.0275
# ...              ...        ...       ...       ...  ...        ...
# 2191.9247  5202.7729  5879.7636  604.3534  302.0359  0.0 -4510.7130
# 2185.1726  5260.1256  5884.4024  614.7070  307.8136  0.0 -4488.7698
# 2139.1549  5274.8007  6064.2025  605.4493  307.1541  0.0 -4530.4652
# 2171.7923  5284.0448  5967.2504  587.5678  316.6032  0.0 -4572.0010
# 2133.1228  5156.0855  5960.9138  571.0379  309.0484  0.0 -4554.8932
#
#                1-4VDW     1-4ELE      RESTR     ECAVITY  EDISPER
# 2125.5579 -38262.4658 -5508.0115  2324.4247  30833.4680      0.0
# ...

# %%
netoopen["complex"]
# Out:
#                 BOND      ANGLE     DIHED    VDWAAL  ELE        EPB  \
# 2125.5579  5199.4285  6063.4239  573.2902  318.6887  0.0 -4521.5888
# 2131.5706  5263.8231  5910.4996  590.3997  298.6390  0.0 -4509.5023
# 2121.5835  5160.9686  5889.1940  588.8470  320.4662  0.0 -4522.9566
# 2162.9714  5132.7700  5941.9835  597.2895  328.2941  0.0 -4483.0713
# 2098.7587  5282.9880  5906.8351  599.9389  301.6552  0.0 -4518.0275
# ...              ...        ...       ...       ...  ...        ...
# 2191.9247  5202.7729  5879.7636  604.3534  302.0359  0.0 -4510.7130
# 2185.1726  5260.1256  5884.4024  614.7070  307.8136  0.0 -4488.7698
# 2139.1549  5274.8007  6064.2025  605.4493  307.1541  0.0 -4530.4652
# 2171.7923  5284.0448  5967.2504  587.5678  316.6032  0.0 -4572.0010
# 2133.1228  5156.0855  5960.9138  571.0379  309.0484  0.0 -4554.8932
#
#                1-4VDW     1-4ELE      RESTR     ECAVITY  EDISPER
# 2125.5579 -38262.4658 -5508.0115  2324.4247  30833.4680      0.0
# ...

# %%
netoopen["ligand"]
# Out:
#               BOND     ANGLE    DIHED   VDWAAL  ELE       EPB     1-4VDW  \
# 277.3397  771.5935  910.7844  84.8112  45.0435  0.0 -449.9309 -2558.3466
# 272.5007  783.6444  858.5971  88.6522  48.9101  0.0 -470.3188 -2565.1806
# 305.6972  767.8026  859.0396  84.6183  43.7719  0.0 -489.7357 -2631.5280
# 293.4792  723.8765  899.0447  86.5417  46.5294  0.0 -455.7443 -2632.1375
# 294.7019  806.7455  867.7188  99.7701  49.6502  0.0 -450.3756 -2489.0322
# ...            ...       ...      ...      ...  ...       ...        ...
# 301.9937  764.6773  844.1257  91.1517  35.6599  0.0 -423.4723 -2361.2365
# 277.9131  750.6376  849.6058  85.2398  33.9653  0.0 -408.9372 -2316.6974
# 288.0149  777.3039  912.7633  93.2658  44.0393  0.0 -438.2130 -2580.5507
# 287.3126  780.4771  886.2821  83.4735  39.8215  0.0 -436.2683 -2538.5679
# 297.9003  722.8181  880.8945  83.4971  40.1777  0.0 -443.5017 -2493.2520
#
#              1-4ELE     RESTR    ECAVITY  EDISPER
# ...
