# %%
import matplotlib 
import matplotlib.pylab as plt
import numpy as np
matplotlib.rcParams['figure.figsize']=(3,1.75)
matplotlib.rcParams['figure.dpi'] = 400
# %matplotlib inline

# %%
    plt.plot(xdata,ydata,"o-",color=color,label=label,markersize=2,markeredgewidth=0.1)
    plt.xlabel("Distance ($\AA$)")
    plt.xticks(**font)
    plt.yticks(**font)
    plt.ylim([0,3])
    plt.xlim([0,12])
    plt.title(title,**font)
    plt.ylabel("Wat-Oxy density(1/$\AA^{3}$)")

# %%
cases=["apv_1RWY_Ca","apv_1S3P_Ca", "apv_1XVJ_Ca","bpv_1G33_Ca","bpv_1G33_Mg","bpv_1RRO_Ca"]
rootdir="/net/share/bsu233/temp/PV-rdf/"

datasetname=["naardf1","naardf2","nwrdf1","nwrdf2"]

# %%
class empty: pass

#casedata = empty
#casedata.indx=[]

totaldata=[]
for i in np.arange(6):
    casedata=[]
    for j in np.arange(4):
        
        datafile= rootdir + cases[i] + "/" + datasetname[j] 
        data=np.loadtxt(datafile,comments='#')
        casedata.append(data)
    totaldata.append(casedata)
        #print datafile

# %%
matplotlib.rcParams['figure.figsize']=(3,2)
matplotlib.rcParams['figure.dpi'] = 300
plt.plot(totaldata[0][0][:,0],totaldata[0][0][:,1],"o-",color="red",label=r'$\alpha$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[1][0][:,0],totaldata[1][0][:,1],"o-",color="lightcoral",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[2][0][:,0],totaldata[2][0][:,1],"o-",color="orangered",label=r'$\alpha$PV D94S/G98E Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[3][0][:,0],totaldata[3][0][:,1],"o-",color="cornflowerblue",label=r'$\Delta \beta$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[4][0][:,0],totaldata[4][0][:,1],"--",color="cornflowerblue",label=r'$\Delta \beta$PV Mg$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[5][0][:,0],totaldata[5][0][:,1],"o-",color="blue",label=r'$\beta$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.xlabel("Distance ($\AA$)")
plt.xticks(**font)
plt.yticks(**font)
plt.ylim([0,3])
plt.legend(fontsize=5.5,handlelength=3)
plt.xlim([0,5])
plt.title("CD Site",**font)
plt.ylabel("a.a-Oxy density(1/$\AA^{3}$)")

# %%
plt.plot(totaldata[0][1][:,0],totaldata[0][1][:,1],"o-",color="red",label=r'$\alpha$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[1][1][:,0],totaldata[1][1][:,1],"o-",color="lightcoral",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[2][1][:,0],totaldata[2][1][:,1],"o-",color="orangered",label=r'$\alpha$PV D94S/G98E Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[3][1][:,0],totaldata[3][1][:,1],"o-",color="cornflowerblue",label=r'$\Delta \beta$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[4][1][:,0],totaldata[4][1][:,1],"--",color="cornflowerblue",label=r'$\Delta \beta$PV Mg$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[5][1][:,0],totaldata[5][1][:,1],"o-",color="blue",label=r'$\beta$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.xlabel("Distance ($\AA$)")
plt.xticks(**font)
plt.yticks(**font)
plt.ylim([0,3])
plt.legend(fontsize=5.5,handlelength=3)
plt.xlim([0,5])
plt.title("EF Site",**font)
plt.ylabel("a.a-Oxy density(1/$\AA^{3}$)")

# %%
plt.plot(totaldata[0][2][:,0],totaldata[0][2][:,1],"o-",color="red",label=r'$\alpha$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[1][2][:,0],totaldata[1][2][:,1],"o-",color="lightcoral",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[2][2][:,0],totaldata[2][2][:,1],"o-",color="orangered",label=r'$\alpha$PV D94S/G98E Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[3][2][:,0],totaldata[3][2][:,1],"o-",color="cornflowerblue",label=r'$\Delta \beta$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[4][2][:,0],totaldata[4][2][:,1],"--",color="cornflowerblue",label=r'$\Delta \beta$PV Mg$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[5][2][:,0],totaldata[5][2][:,1],"o-",color="blue",label=r'$\beta$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.xlabel("Distance ($\AA$)")
plt.xticks(**font)
plt.yticks(**font)
plt.ylim([0,0.5])
plt.legend(fontsize=5.5,handlelength=3)
plt.xlim([0,5])
plt.title("CD Site",**font)
plt.ylabel("Wat-Oxy density(1/$\AA^{3}$)")

# %%
plt.plot(totaldata[0][3][:,0],totaldata[0][3][:,1],"o-",color="red",label=r'$\alpha$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[1][3][:,0],totaldata[1][3][:,1],"o-",color="lightcoral",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[2][3][:,0],totaldata[2][3][:,1],"o-",color="orangered",label=r'$\alpha$PV D94S/G98E Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[3][3][:,0],totaldata[3][3][:,1],"o-",color="cornflowerblue",label=r'$\Delta \beta$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[4][3][:,0],totaldata[4][3][:,1],"--",color="cornflowerblue",label=r'$\Delta \beta$PV Mg$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.plot(totaldata[5][3][:,0],totaldata[5][3][:,1],"o-",color="blue",label=r'$\beta$PV Ca$^{2+}$',markersize=2,markeredgewidth=0.1)
plt.xlabel("Distance ($\AA$)")
plt.xticks(**font)
plt.yticks(**font)
plt.ylim([0,0.5])
plt.legend(fontsize=5.5,handlelength=3)
plt.xlim([0,5])
plt.title("EF Site",**font)
plt.ylabel("Wat-Oxy density(1/$\AA^{3}$)")

# %%
print np.max(totaldata[0][0][:,1])
cdmaxaa=[]
cdmaxwat=[]
efmaxaa=[]
efmaxwat=[]
for i in np.arange(6):
    cdmaxaa.append(np.max(totaldata[i][0][:,1]))
    efmaxaa.append(np.max(totaldata[i][1][:,1]))
    cdmaxwat.append(np.max(totaldata[i][2][:,1]))
    efmaxwat.append(np.max(totaldata[i][3][:,1]))
# Out:
# 1.73306

# %%
width=0.6
cdbarlist=[]
efbarlist=[]
for i in np.arange(6):
    aa = 0 + i*0.64
    bb = 5 + i*0.64
    cdbarlist.append(aa)
    efbarlist.append(bb)

print  cdbarlist
# Out:
# [0.0, 0.64000000000000001, 1.28, 1.9199999999999999, 2.5600000000000001, 3.2000000000000002]

# %%
matplotlib.rcParams['figure.figsize'] = (3,2)
matplotlib.rcParams['savefig.dpi'] = 300

barlist = plt.bar(cdbarlist,cdmaxaa,width,align='center')
barlist[0].set_color('red')
barlist[1].set_color('lightcoral')
#barlist[1].set_edgecolor('black')

barlist[2].set_color('orangered')
barlist[3].set_color('cornflowerblue')
barlist[4].set_color('cornflowerblue')
barlist[5].set_color('blue')
barlist[4].set_hatch(".")
barlist[4].set_edgecolor('black')
#barlist[4].set_hatch

#barlist2 = plt.bar(efbarlist,efmaxaa,width,align='center',edgecolor="black",error_kw=dict(ecolor='m',lw=2,capsize=6,capthick=2))
#barlist2[0].set_color('red')
#barlist2[1].set_color('lightcoral')
#barlist[1].set_edgecolor('black')

#barlist2[2].set_color('orangered')
#barlist2[3].set_color('cornflowerblue')
#barlist2[4].set_color('cornflowerblue')
#barlist2[5].set_color('blue')

#barlist2[3].set_hatch("+")

Rmsd=[r'$\alpha$PV',r'$\alpha$PV S55D/E59D',r'$\alpha$PV D94S/G98E',r'$\Delta \beta$PV'\
      ,r'$\Delta \beta$PV Mg',r'$\beta$PV']
plt.xticks(cdbarlist,Rmsd,fontsize=6,rotation=-45)
plt.ylim([0,3])
plt.yticks(**font)

plt.title("CD Site",**font)
plt.ylabel("aa-Oxy Max Density(1/$\AA^{3}$)")
print cdbarlist
# Out:
# [0.0, 0.64000000000000001, 1.28, 1.9199999999999999, 2.5600000000000001, 3.2000000000000002]

# %%
barlist = plt.bar(cdbarlist,efmaxaa,width,align='center')
barlist[0].set_color('red')
barlist[1].set_color('lightcoral')
#barlist[1].set_edgecolor('black')

barlist[2].set_color('orangered')
barlist[3].set_color('cornflowerblue')
barlist[4].set_color('cornflowerblue')
barlist[5].set_color('blue')
barlist[4].set_hatch(".")
barlist[4].set_edgecolor('black')
#barlist[4].set_hatch

#barlist2 = plt.bar(efbarlist,efmaxaa,width,align='center',edgecolor="black",error_kw=dict(ecolor='m',lw=2,capsize=6,capthick=2))
#barlist2[0].set_color('red')
#barlist2[1].set_color('lightcoral')
#barlist[1].set_edgecolor('black')

#barlist2[2].set_color('orangered')
#barlist2[3].set_color('cornflowerblue')
#barlist2[4].set_color('cornflowerblue')
#barlist2[5].set_color('blue')

#barlist2[3].set_hatch("+")

Rmsd=[r'$\alpha$PV',r'$\alpha$PV S55D/E59D',r'$\alpha$PV D94S/G98E',r'$\Delta \beta$PV'\
      ,r'$\Delta \beta$PV Mg',r'$\beta$PV']
plt.xticks(cdbarlist,Rmsd,fontsize=6,rotation=-45)
plt.ylim([0,3])
plt.yticks(**font)

plt.title("EF Site",**font)
plt.ylabel("aa-Oxy Max Density(1/$\AA^{3}$)")

# %%
barlist = plt.bar(cdbarlist,cdmaxwat,width,align='center')
barlist[0].set_color('red')
barlist[1].set_color('lightcoral')
#barlist[1].set_edgecolor('black')

barlist[2].set_color('orangered')
barlist[3].set_color('cornflowerblue')
barlist[4].set_color('cornflowerblue')
barlist[5].set_color('blue')
barlist[4].set_hatch(".")
barlist[4].set_edgecolor('black')
#barlist[4].set_hatch

#barlist2 = plt.bar(efbarlist,efmaxaa,width,align='center',edgecolor="black",error_kw=dict(ecolor='m',lw=2,capsize=6,capthick=2))
#barlist2[0].set_color('red')
#barlist2[1].set_color('lightcoral')
#barlist[1].set_edgecolor('black')

#barlist2[2].set_color('orangered')
#barlist2[3].set_color('cornflowerblue')
#barlist2[4].set_color('cornflowerblue')
#barlist2[5].set_color('blue')

#barlist2[3].set_hatch("+")

Rmsd=[r'$\alpha$PV',r'$\alpha$PV S55D/E59D',r'$\alpha$PV D94S/G98E',r'$\Delta \beta$PV'\
      ,r'$\Delta \beta$PV Mg',r'$\beta$PV']
plt.xticks(cdbarlist,Rmsd,fontsize=6,rotation=-45)
plt.ylim([0,0.5])
plt.yticks(**font)

plt.title("CD Site",**font)
plt.ylabel("Wat-Oxy Max Density(1/$\AA^{3}$)")

# %%
barlist = plt.bar(cdbarlist,efmaxwat,width,align='center')
barlist[0].set_color('red')
barlist[1].set_color('lightcoral')
#barlist[1].set_edgecolor('black')

barlist[2].set_color('orangered')
barlist[3].set_color('cornflowerblue')
barlist[4].set_color('cornflowerblue')
barlist[5].set_color('blue')
barlist[4].set_hatch(".")
barlist[4].set_edgecolor('black')
#barlist[4].set_hatch

#barlist2 = plt.bar(efbarlist,efmaxaa,width,align='center',edgecolor="black",error_kw=dict(ecolor='m',lw=2,capsize=6,capthick=2))
#barlist2[0].set_color('red')
#barlist2[1].set_color('lightcoral')
#barlist[1].set_edgecolor('black')

#barlist2[2].set_color('orangered')
#barlist2[3].set_color('cornflowerblue')
#barlist2[4].set_color('cornflowerblue')
#barlist2[5].set_color('blue')

#barlist2[3].set_hatch("+")

Rmsd=[r'$\alpha$PV',r'$\alpha$PV S55D/E59D',r'$\alpha$PV D94S/G98E',r'$\Delta \beta$PV'\
      ,r'$\Delta \beta$PV Mg',r'$\beta$PV']
plt.xticks(cdbarlist,Rmsd,fontsize=6,rotation=-45)
plt.ylim([0,0.5])
plt.yticks(**font)

plt.title("EF Site",**font)
plt.ylabel("Wat-Oxy Max Density(1/$\AA^{3}$)")

# %%
font = {'weight': 'bold',
        'size':8
        }
plotfigure(totaldata[0][0][:,0],totaldata[0][0][:,1],color="red",title='Ca$^{2}$ at Site 1',**font)

# %%
plotfigure(totaldata[1][:,0],totaldata[1][:,1],color="red",title='Ca$^{2}$ at Site 1',**font)

# %%
plotfigure(totaldata[7][:,0],totaldata[7][:,1],color="green",title='K$^{+}$ at Site 1',**font)

# %%
directory="/net/share/bsu233/bdsSERCA/"
cases=["Ca"]
runs=["1","2"]
totaldata=[]

for j in runs:
    
    datafile= directory + cases[0] + "/run" + j + "/rdf/t2"
    data=np.loadtxt(datafile,comments='#')
    totaldata.append(data)

# %%
plotfigure(totaldata[1][:,0],totaldata[1][:,1],color="salmon",title='Ca$^{2+}$ at Site 2',**font)

# %%
# amino acid coordination pattern

Ca1file = "/home/AD/bsu233/plotfigures/SERCA_MSA/Cacoord_rdf/CA1"
Ca2file = "/home/AD/bsu233/plotfigures/SERCA_MSA/Cacoord_rdf/CA2"
Mgfile="/home/AD/bsu233/plotfigures/SERCA_MSA/Mgcoord_rdf/MG"
Kdfile = "/home/AD/bsu233/plotfigures/SERCA_MSA/Kcoord_rdf/K"

datafile=[Ca1file,Ca2file,Mgfile,Kdfile]
aminoaciddata=[]
for i in np.arange(4):
    aminoaciddata.append(np.loadtxt(datafile[i]))
    


#plt.plot(plt.plot(xdata,ydata,"o-",color=color,label=label,markersize=2,markeredgewidth=0.1))

# %%
lw=0.5
elw=0.3
cpsize=0.8
plt.errorbar(aminoaciddata[0][:,0],aminoaciddata[0][:,1],linewidth=lw,elinewidth=elw,capsize=cpsize,color="red",yerr=aminoaciddata[0][:,2],label="Ca$^{2+}$ at Site 1")
plt.errorbar(aminoaciddata[1][:,0],aminoaciddata[1][:,1],linewidth=lw,elinewidth=elw,capsize=cpsize,color="salmon",yerr=aminoaciddata[0][:,2],label="Ca$^{2+}$ at Site 2")
plt.errorbar(aminoaciddata[2][:,0],aminoaciddata[2][:,1],linewidth=lw,elinewidth=elw,capsize=cpsize,color="blue",yerr=aminoaciddata[0][:,2],label="Mg$^{2+}$")
plt.errorbar(aminoaciddata[3][:,0],aminoaciddata[3][:,1],linewidth=lw,elinewidth=elw,capsize=cpsize,color="green",yerr=aminoaciddata[0][:,2],label="K$^{+}$")
leg=plt.legend(fontsize=4)
leg.get_frame().set_linewidth(0.5)
plt.xlim([0,12])
plt.ylim([0,8])
#plt.yticks(np.arange[0,],[0,2,4,6,8])
plt.xlabel("Distance ($\AA$)")
plt.xticks(**font)
plt.yticks(**font)
    #plt.ylim([0,1])
    #plt.xlim([0,12])
#plt.title(,**font)
plt.ylabel("a.a-Oxy Count")

# %%
Ca1file = "/home/AD/bsu233/plotfigures/SERCA_MSA/Cacoord_wrdf/CA1"
Ca2file = "/home/AD/bsu233/plotfigures/SERCA_MSA/Cacoord_wrdf/CA2"
Mgfile="/home/AD/bsu233/plotfigures/SERCA_MSA/Mgcoord_wrdf/MG"
Kdfile = "/home/AD/bsu233/plotfigures/SERCA_MSA/Kcoord_wrdf/K"

datafile=[Ca1file,Ca2file,Mgfile,Kdfile]
aminoaciddata=[]
for i in np.arange(4):
    aminoaciddata.append(np.loadtxt(datafile[i]))

# %%
lw=0.5
elw=0.3
cpsize=0.8
plt.errorbar(aminoaciddata[0][:,0],aminoaciddata[0][:,1],linewidth=lw,elinewidth=elw,capsize=cpsize,color="red",yerr=aminoaciddata[0][:,2],label="Ca$^{2+}$ at Site 1")
plt.errorbar(aminoaciddata[1][:,0],aminoaciddata[1][:,1],linewidth=lw,elinewidth=elw,capsize=cpsize,color="salmon",yerr=aminoaciddata[0][:,2],label="Ca$^{2+}$ at Site 2")
plt.errorbar(aminoaciddata[2][:,0],aminoaciddata[2][:,1],linewidth=lw,elinewidth=elw,capsize=cpsize,color="blue",yerr=aminoaciddata[0][:,2],label="Mg$^{2+}$")
plt.errorbar(aminoaciddata[3][:,0],aminoaciddata[3][:,1],linewidth=lw,elinewidth=elw,capsize=cpsize,color="green",yerr=aminoaciddata[0][:,2],label="K$^{+}$")
leg=plt.legend(fontsize=4)
leg.get_frame().set_linewidth(0.5)
plt.xlim([0,12])
plt.ylim([0,1])
#plt.yticks(np.arange[0,],[0,2,4,6,8])
plt.xlabel("Distance ($\AA$)")
plt.xticks(**font)
plt.yticks(**font)
    #plt.ylim([0,1])
    #plt.xlim([0,12])
#plt.title(,**font)
plt.ylabel("Wat-Oxy Den(1/$\AA^{3})$")
