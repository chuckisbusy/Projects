# %%
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pylab as plt
from matplotlib import gridspec
from pylab import rcParams
# %matplotlib inline

# %%
rcParams['figure.figsize'] = 15,10
rcParams['axes.linewidth'] = 4.0
rcParams['savefig.dpi'] = 500
rcParams['pdf.fonttype'] = 42
rcParams['ps.fonttype'] = 42

# %% [markdown]
# ### ---- Just plotting 1 test case ----

# %%
file="/net/share/cad234/projects/pv/apv_1XVJ_Mg/pbsa-per-res/total_e_decomp.dat"
data=np.genfromtxt(file)
index=np.arange(len(data))
plt.bar(index, data, align='center', alpha=1.0,)
plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('Contribution Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.title('\u03B1PV 1XVJ Mg D94S/G98E',fontsize=35)
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.show
#plt.savefig("decomp1.pdf", transparent=True)
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(index,data,"o-",color="blue",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',markersize=6,markeredgewidth=0.6)
plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('Contribution Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.title('\u03B1PV 1XVJ Mg D94S/G98E',fontsize=35)
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.show
#plt.savefig("decomp2.pdf", transparent=True)
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### ---- Plotting multiple cases ----

# %%
cases=["apv_1RWY_Ca", "apv_1RWY_Mg", "apv_1S3P_Ca", "apv_1S3P_Mg", "apv_1XVJ_Ca", "apv_1XVJ_Mg","bpv_1G33_Ca", "bpv_1G33_Mg",  "bpv_1RRO_Ca", "bpv_1RRO_Mg"]
loc="/net/share/cad234/projects/pv/"

# %%
casedata=[]
for i in np.arange(10):
    datafile= loc + cases[i] + "/pbsa-per-res/total_e_decomp.dat"
    data=np.loadtxt(datafile,comments='#')
    casedata.append(data)

# %%
x=np.arange(len(casedata[0]))
plt.plot(x,casedata[0],color='red',marker="o",label=r'$\alpha$PV Ca$^{2+}$',linestyle='solid',linewidth='4',markersize=6)
plt.plot(x,casedata[1],color='lightcoral',marker="o",label=r'$\alpha$PV Mg$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,casedata[2],color='orangered',marker="o",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,casedata[3],color='cornflowerblue',marker="o",label=r'$\alpha$PV S55D/E59D Mg$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,casedata[4],color='blue',marker="o",label=r'$\alpha$PV D94S/G98E Ca$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,casedata[5],color='green',marker="o",label=r'$\alpha$PV D94S/G98E Mg$^{2+}$',linestyle='dashed',markersize=6)
plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('Contribution Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('\u03B1PV WT and Mutants',fontsize=35)
#plt.savefig("decmp1.pdf", transparent=True)
# Out:
# Text(0.5,1,'αPV WT and Mutants')

# %% [markdown]
# ### ---- Plotting Total E bPV cases ----

# %%
x = np.r_[0:108]
plt.plot(x,np.pad(casedata[6][:72], (36,0), 'constant'),color='red',marker="o",label=r'$\Delta \beta$PV Ca$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,np.pad(casedata[7][:72], (36,0), 'constant'),color='blue',marker="o",label=r'$\Delta \beta$PV Mg$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,casedata[8],color='red',marker="o",label=r'$\beta$PV Ca$^{2+}$',linestyle='solid',linewidth='4',markersize=10)
plt.plot(x,casedata[9],color='blue',marker="o",label=r'$\beta$PV Mg$^{2+}$',linestyle='solid',linewidth='4',markersize=10)
plt.xlim(xmin=35)
plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('Total Contribution Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('\u0394\u03B2PV and WT',fontsize=35)
plt.savefig("decmp2.pdf", transparent=True)

# %% [markdown]
# ### ---- Plotting Total E aPV cases ----

# %%
smalldata=[]
left=[]
right=[]
for i in np.arange(10):
    tmp1 = casedata[i][49:63]
    tmp2 = casedata[i][88:102]
    left.append(tmp1)
    right.append(tmp2)

# %%
x1 = np.r_[50:64]
x2 = np.r_[89:103]
fig = plt.figure(figsize=(20, 10))
gs = gridspec.GridSpec(1,2)
ax = fig.add_subplot(gs[:, 0])
ax2 = fig.add_subplot(gs[:, 1])
#Left plot
#ax1.plot(x1,left[0],color='red',marker="o",label=r'$\alpha$PV Ca$^{2+}$',linestyle='dashed',markersize=6)
ax.plot(x1,left[1]-left[0],color='blue',marker="o",label=r'$\alpha$PV Mg$^{2+}$',linestyle='dashed',markersize=6)
ax.plot(x1,left[2]-left[0],color='red',marker="o",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',linestyle='solid',linewidth='8',markersize=12)
ax.plot(x1,left[3]-left[0],color='blue',marker="o",label=r'$\alpha$PV S55D/E59D Mg$^{2+}$',linestyle='solid',linewidth='8',markersize=12)
ax.plot(x1,left[4]-left[0],color='red',marker="o",label=r'$\alpha$PV D94S/G98E Ca$^{2+}$',linestyle='solid',linewidth='1',markersize=8)
ax.plot(x1,left[5]-left[0],color='blue',marker="o",label=r'$\alpha$PV D94S/G98E Mg$^{2+}$',linestyle='solid',linewidth='1',markersize=8)
#Right plot
#ax2.plot(x2,right[0],color='red',marker="o",label=r'$\alpha$PV Ca$^{2+}$',linestyle='dashed',markersize=6)
ax2.plot(x2,right[1]-right[0],color='blue',marker="o",label=r'$\alpha$PV Mg$^{2+}$',linestyle='dashed',markersize=8)
ax2.plot(x2,right[2]-right[0],color='red',marker="o",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',linestyle='solid',linewidth='8',markersize=12)
ax2.plot(x2,right[3]-right[0],color='blue',marker="o",label=r'$\alpha$PV S55D/E59D Mg$^{2+}$',linestyle='solid',linewidth='8',markersize=12)
ax2.plot(x2,right[4]-right[0],color='red',marker="o",label=r'$\alpha$PV D94S/G98E Ca$^{2+}$',linestyle='solid',linewidth='1',markersize=8)
ax2.plot(x2,right[5]-right[0],color='blue',marker="o",label=r'$\alpha$PV D94S/G98E Mg$^{2+}$',linestyle='solid',linewidth='1',markersize=8)

ax2.legend(fontsize=19,handlelength=2,loc="best")
ax.set_ylabel('Contribution Energy (kcal/mol)', fontsize=30)
ax.set_xticks(np.arange(50,64,2))
ax.tick_params(axis='both', which='major', direction='in', labelsize=28, length=9, width=4)
ax.set_xlabel("R",x=1.1,fontsize=30)
ax2.set_xticks(np.arange(89,103,2))
ax2.tick_params(axis='both', which='major', direction='in', labelsize=28, length=9, width=4)

plt.tight_layout()
plt.suptitle('\u03B1PV WT and Mutants',fontsize=35)
plt.subplots_adjust(top=.90)
plt.savefig("newdecmp1.pdf", transparent=True)

# %% [markdown]
# ### ---- Plotting VDW Energy Contributions ----

# %%
vdw=[]
for i in np.arange(10):
    datafile= loc + cases[i] + "/pbsa-per-res/vdw.dat"
    data=np.loadtxt(datafile,comments='#')
    vdw.append(data)

# %%
x=np.arange(len(vdw[0]))
plt.plot(x,vdw[0],color='red',marker="o",label=r'$\alpha$PV Ca$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,vdw[1],color='blue',marker="o",label=r'$\alpha$PV Mg$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,vdw[2],color='red',marker="o",label=r'$\alpha$PV S55D/E59D Ca$^{2+}$',linestyle='solid',linewidth='4',markersize=10)
plt.plot(x,vdw[3],color='blue',marker="o",label=r'$\alpha$PV S55D/E59D Mg$^{2+}$',linestyle='solid',linewidth='4',markersize=10)
plt.plot(x,vdw[4],color='red',marker="o",label=r'$\alpha$PV D94S/G98E Ca$^{2+}$',linestyle='solid',linewidth='1',markersize=8)
plt.plot(x,vdw[5],color='blue',marker="o",label=r'$\alpha$PV D94S/G98E Mg$^{2+}$',linestyle='solid',linewidth='1',markersize=8)
plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('VDW Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('\u03B1PV',fontsize=35)
#plt.savefig("decmp1a.pdf", transparent=True)
# Out:
# Text(0.5,1,'αPV')

# %%
x=np.arange(len(vdw[8]))
plt.plot(x,np.pad(vdw[6][:72], (36,0), 'constant'),color='red',marker="o",label=r'$\Delta \beta$PV Ca$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,np.pad(vdw[7][:72], (36,0), 'constant'),color='blue',marker="o",label=r'$\Delta \beta$PV Mg$^{2+}$',linestyle='dashed',markersize=6)
plt.plot(x,vdw[8],color='red',marker="o",label=r'$\beta$PV Ca$^{2+}$',linestyle='solid',linewidth='4',markersize=10)
plt.plot(x,vdw[9],color='blue',marker="o",label=r'$\beta$PV Mg$^{2+}$',linestyle='solid',linewidth='4',markersize=10)
plt.xlim(xmin=35)
plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('VDW Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('\u03B2PV',fontsize=35)
#plt.savefig("decmp2a.pdf", transparent=True)
# Out:
# Text(0.5,1,'βPV')

# %% [markdown]
# ### Test

# %%
cases=["apv_1RWY_Ca", "apv_1RWY_Mg", "apv_1RWY_apo", "bpv_1RRO_Ca", "bpv_1RRO_Mg", "bpv_1RRO_apo"]
loc="/net/share/cad234/projects/pv/"

# %%
vdw=[]
for i in np.arange(6):
    datafile= loc + cases[i] + "/pbsa-per-res/vdw.dat"
    data=np.loadtxt(datafile,comments='#')
    vdw.append(data)

# %%
x=np.arange(len(vdw[0]))
plt.plot(x,vdw[0],color='red',marker="o",linestyle='solid',markersize=6, label='Ca')
plt.plot(x,vdw[1],color='blue',marker="o",linestyle='solid',markersize=6, label='Mg')
plt.plot(x,vdw[2],color='green',marker="o",linestyle='solid',markersize=6, label='Apo')

plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('VDW Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('\u03B1PV WT 1RWY',fontsize=35)
#plt.savefig("vdw-pv.pdf", transparent=True)
# Out:
# Text(0.5,1,'αPV WT 1RWY')

# %%
plt.plot(x,vdw[3],color='red',marker="o",linestyle='solid',markersize=6, label='Ca')
plt.plot(x,vdw[4],color='blue',marker="o",linestyle='solid',markersize=6, label='Mg')
plt.plot(x,vdw[5],color='green',marker="o",linestyle='solid',markersize=6, label='Apo')

plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('VDW Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('\u03B2PV WT 1RRO',fontsize=35)
#plt.savefig("vdw-pv.pdf", transparent=True)
# Out:
# Text(0.5,1,'βPV WT 1RRO')

# %%
diffapv=vdw[0]-vdw[2]
diffbpv=vdw[3]-vdw[5]

plt.plot(x,diffapv,color='k',marker="o",linestyle='solid',markersize=6)
plt.plot(x,diffbpv,color='magenta',marker="o",linestyle='solid',markersize=6)

plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('VDW Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
#plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('WT Diff: $Ca^{2+}$ - Apo',fontsize=35)
#plt.savefig("vdw-diff.pdf", transparent=True)
# Out:
# Text(0.5,1,'WT Diff: $Ca^{2+}$ - Apo')

# %%
vdw=[]
CaVDW="/net/share/cad234/projects/pv/apv_1RWY_Ca/pbsa-per-res/vdw.dat"
MgVDW="/net/share/cad234/projects/pv/apv_1RWY_Mg/pbsa-per-res/vdw.dat"
ApoVDW="/net/share/cad234/projects/pv/apv_1RWY_apo/pbsa-per-res/vdw.dat"
Ca=np.loadtxt(CaVDW,comments='#')
Mg=np.loadtxt(MgVDW,comments='#')
Apo=np.loadtxt(ApoVDW,comments='#')

# %%
x=np.arange(len(Ca))
plt.plot(x,Ca,color='red',marker="o",linestyle='solid',markersize=6, label='Ca')
plt.plot(x,Mg,color='blue',marker="o",linestyle='solid',markersize=6, label='Mg')
plt.plot(x,Apo,color='green',marker="o",linestyle='solid',markersize=6, label='Apo')

plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('VDW Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('\u03B1PV WT 1RWY',fontsize=35)
#plt.savefig("vdw-pv.pdf", transparent=True)
# Out:
# Text(0.5,1,'αPV WT 1RWY')

# %%
new=Ca-Apo
x=np.arange(len(Ca))
plt.plot(x,new,color='k',marker="o",linestyle='dashed',markersize=6)

plt.xlabel('Residue Numbers', fontsize=25)
plt.ylabel('VDW Energy (kcal/mol)', fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
#plt.legend(fontsize=18,handlelength=2,loc="best")
plt.tick_params(which='both',direction='in',length=8, width=3,)
plt.title('\u03B1PV WT 1RWY Diff: $Ca^{2+}$ - Apo',fontsize=35)
#plt.savefig("vdw-diff.pdf", transparent=True)
# Out:
# Text(0.5,1,'αPV WT 1RWY Diff: $Ca^{2+}$ - Apo')

# %% [markdown]
# Getting each items position in the diff data set, the new array: new.
